# %% [markdown]
# # Data Understanding

# %% [markdown]
# # First Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
listing = pd.read_csv('listings.csv')
listing.head(5)
# Out:
#       id                                               name  host_id  \
# 0  15007    Blaauwberg House on the beach in Bloubergstrand    59072
# 1  15068                                         Grande Bay    59318
# 2  15077                      Relaxed beach living in style    59342
# 3  15199                            Self catering apartment    59694
# 4  15354  Aurora Self Catering Units, Durbanville, Cape ...    60196
#
#   host_name  neighbourhood_group neighbourhood   latitude  longitude  \
# 0      Dirk                  NaN       Ward 23 -33.800010  18.460630
# 1     Linda                  NaN       Ward 23 -33.788260  18.459400
# 2     Georg                  NaN        Ward 4 -33.858356  18.490376
# 3     Alexa                  NaN      Ward 115 -33.911150  18.412350
# 4       Ian                  NaN      Ward 112 -33.830740  18.631420
#
#          room_type   price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listing.isna().sum()
# Out:
# id                                    0
# name                                  1
# host_id                               0
# host_name                             6
# neighbourhood_group               26877
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              4401
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        6124
# reviews_per_month                  6124
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           26748
# dtype: int64

# %%
listing.duplicated().sum()
# Out:
# 0

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26877 entries, 0 to 26876
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26877 non-null  int64
#  1   name                            26876 non-null  object
#  2   host_id                         26877 non-null  int64
#  3   host_name                       26871 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   26877 non-null  object
#  6   latitude                        26877 non-null  float64
#  7   longitude                       26877 non-null  float64
#  8   room_type                       26877 non-null  object
#  9   price                           22476 non-null  float64
#  10  minimum_nights                  26877 non-null  int64
#  11  number_of_reviews               26877 non-null  int64
# ...

# %%
sns.boxplot(listing)
# Out:
# <Axes: >

# %%
listing.shape
# Out:
# (26877, 18)

# %%
listing.describe()
# Out:
#                  id       host_id  neighbourhood_group      latitude  \
# count  2.687700e+04  2.687700e+04                  0.0  26877.000000
# mean   7.010873e+17  2.253725e+08                  NaN    -33.954672
# std    5.826912e+17  2.190787e+08                  NaN      0.098098
# min    1.500700e+04  2.528600e+04                  NaN    -34.262840
# 25%    3.809275e+07  3.865032e+07                  NaN    -34.014110
# 50%    8.500092e+17  1.314201e+08                  NaN    -33.926913
# 75%    1.262130e+18  4.152172e+08                  NaN    -33.909730
# max    1.519110e+18  7.209347e+08                  NaN    -33.485066
#
#           longitude          price  minimum_nights  number_of_reviews  \
# count  26877.000000   22476.000000    26877.000000       26877.000000
# mean      18.472992    3280.999778        4.501618          24.719165
# std        0.124027    9048.338102       21.764125          48.541829
# ...

# %% [markdown]
# # Second Dataset

# %%
neighbor = pd.read_csv('neighbourhoods.csv')
neighbor.head()
# Out:
#    neighbourhood_group neighbourhood
# 0                  NaN        Ward 1
# 1                  NaN       Ward 10
# 2                  NaN      Ward 100
# 3                  NaN      Ward 101
# 4                  NaN      Ward 102

# %%
neighbor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        116 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 1.9+ KB

# %%
neighbor.isna().sum()
# Out:
# neighbourhood_group    116
# neighbourhood            0
# dtype: int64

# %%
neighbor = neighbor.drop(columns = 'neighbourhood_group', axis = 1)
neighbor
# Out:
#     neighbourhood
# 0          Ward 1
# 1         Ward 10
# 2        Ward 100
# 3        Ward 101
# 4        Ward 102
# ..            ...
# 111       Ward 95
# 112       Ward 96
# 113       Ward 97
# 114       Ward 98
# 115       Ward 99
#
# [116 rows x 1 columns]

# %%
neighbor.duplicated().sum()
# Out:
# 0

# %%
neighbor.shape
# Out:
# (116, 1)

# %% [markdown]
# # Third Dataset

# %%
review = pd.read_csv('reviews.csv')
review.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       15007   9223897  2013-12-15      7175290         Morne
# 1       15007  53759983  2015-11-12     13937367         Ciske
# 2       15007  55131160  2015-11-28     28986066      Samantha
# 3       15007  60945736  2016-01-30      6769287        Thomas
# 4       15007  61787988  2016-02-08     53613595          Inés
#
#                                             comments
# 0  We spent a fantastic two week holiday at the B...
# 1  Fabulous house in a stunning location! The lov...
# 2  The location of this lovey holiday home is 25m...
# 3  Communication & response very fast and reliabl...
# 4  The location of the house was great!!! the hou...

# %%
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664377 entries, 0 to 664376
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     664377 non-null  int64
#  1   id             664377 non-null  int64
#  2   date           664377 non-null  object
#  3   reviewer_id    664377 non-null  int64
#  4   reviewer_name  664376 non-null  object
#  5   comments       664240 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 30.4+ MB

# %%
review.shape
# Out:
# (664377, 6)

# %%
review.describe()
# Out:
#          listing_id            id   reviewer_id
# count  6.643770e+05  6.643770e+05  6.643770e+05
# mean   2.909628e+17  7.713555e+17  1.998224e+08
# std    4.524698e+17  5.376501e+17  1.803978e+08
# min    1.500700e+04  5.332000e+04  5.600000e+01
# 25%    1.632707e+07  7.232557e+08  4.676191e+07
# 50%    3.672119e+07  8.846239e+17  1.424636e+08
# 75%    7.057951e+17  1.263698e+18  3.243238e+08
# max    1.515762e+18  1.520307e+18  7.207077e+08

# %%
sns.boxplot(review)
# Out:
# <Axes: >

# %%
review.isna().sum()
# Out:
# listing_id         0
# id                 0
# date               0
# reviewer_id        0
# reviewer_name      1
# comments         137
# dtype: int64

# %% [markdown]
# # Data Preparation
