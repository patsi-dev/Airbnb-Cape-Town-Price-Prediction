# %% [markdown]
# # **Airbnb Price Prediction in Cape Town: Advanced Machine Learning Analysis**

# %% [markdown]
# ## **Executive Summary**

# %% [markdown]
# *This project develops a comprehensive machine learning solution to optimize Airbnb pricing in Cape Town's unique tourism market. By combining traditional machine learning with deep learning approaches, we deliver accurate price predictions and actionable insights for hosts, while contributing to the understanding of sharing economy dynamics in African markets. Our hybrid methodology ensures robust performance while exploring cutting-edge techniques.*

# %% [markdown]
# ## **1. Business Understanding**

# %% [markdown]
# ### **1.1 Problem Statement**
# Airbnb hosts in Cape Town face significant challenges in setting optimal prices that balance occupancy rates with revenue maximization. The city's unique tourism patterns, diverse neighborhoods, and seasonal fluctuations create a complex pricing environment that traditional methods struggle to navigate. This project addresses the critical need for data-driven pricing strategies tailored to Cape Town's specific market conditions.

# %% [markdown]
# ### **1.2 Project Objectives**
#
# **Main Objective:**
# Develop an accurate and interpretable machine learning system to predict optimal Airbnb listing prices in Cape Town, providing hosts with data-driven pricing recommendations and insights.
#
# **Specific Objectives:**
# 1. **Implement and compare multiple machine learning approaches** including traditional algorithms and neural networks to identify the most effective pricing prediction methodology for this market
# 2. **Engineer advanced features** that capture Cape Town's unique geographic, seasonal, and amenity-based pricing drivers
# 3. **Build model explainability capabilities** that translate complex predictions into actionable business insights for hosts
# 4. **Develop a deployable pricing tool** that demonstrates practical utility through an interactive web application

# %% [markdown]
# ### **1.3 Success Metrics**
# - **Primary**: RMSE (Root Mean Squared Error) on log-transformed prices targeting <0.15
# - **Secondary**: >70% of predictions within 15% of actual prices
# - **Technical**: R² score >0.65 with comprehensive model explainability
# - **Business**: Clear identification of top 5 pricing drivers in Cape Town market

# %% [markdown]
# ### **1.4 Stakeholder Value**
# - **Airbnb Hosts**: Data-driven pricing decisions increasing revenue by 15-25%
# - **Platform Efficiency**: Reduced price volatility and improved market transparency
# - **Tourism Industry**: Better understanding of Cape Town's accommodation market dynamics
# - **Research Community**: Insights into African sharing economy and emerging market applications

# %% [markdown]
# # 2. Data Understanding

# %% [markdown]
# **Purpose:**
# Gain comprehensive knowledge of the dataset, assess data quality, and identify patterns and relationships before modeling.

# %% [markdown]
# ## 2.1 Data Sources

# %% [markdown]
# The data is from [Inside Airbnb](https://insideairbnb.com/get-the-data/) website.
#
# **What to Do:**
# - Document the exact dataset source and version
# - Record the data collection date and any known limitations
# - List all available features with descriptions
# - Note the initial dataset size and scope
#
# **Expected Example Output:**
# ```
# Dataset: Inside Airbnb Cape Town (28 September 2025)
# Records: 1,800+ listings
# Features: 50+ columns including pricing, amenities, host info, location
# Scope: Active listings in Cape Town metropolitan area
# ```

# %% [markdown]
# ## 2.2 Initial Data Exploration

# %% [markdown]
# **What to Do:**
# ```python
# # Load dataset and perform initial inspection
# df.shape          # Check dimensions (rows, columns)
# df.info()         # Data types and memory usage
# df.head()         # First few rows for visual inspection
# df.describe()     # Statistical summary for numerical features
# df.isnull().sum() # Count missing values per column
# ```
#
# **Key Tasks:**
# - Identify data types (numeric, categorical, text, datetime)
# - Check for obvious data quality issues
# - Understand the structure and organization
# - Note any immediate concerns or surprises

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the dataset
listing = pd.read_csv('listings.csv')
listing.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  15007  https://www.airbnb.com/rooms/15007  20250928034929   2025-09-28
# 1  15068  https://www.airbnb.com/rooms/15068  20250928034929   2025-09-28
# 2  15077  https://www.airbnb.com/rooms/15077  20250928034929   2025-09-28
# 3  15199  https://www.airbnb.com/rooms/15199  20250928034929   2025-09-29
# 4  15354  https://www.airbnb.com/rooms/15354  20250928034929   2025-09-29
#
#             source                                               name  \
# 0      city scrape    Blaauwberg House on the beach in Bloubergstrand
# 1      city scrape                                         Grande Bay
# 2      city scrape                      Relaxed beach living in style
# 3      city scrape                            Self catering apartment
# 4  previous scrape  Aurora Self Catering Units, Durbanville, Cape ...
#
#                                          description  \
# 0  Welcome to our self-catering beach-front famil...
# 1  Modern spacious apartment.  Three bedrooms two...
# 2  Our Superior Rooms (approx. 25 m²) are located...
# 3                                                NaN
# 4  Durbanville is centrally located for daytrips ...
#
#                                neighborhood_overview  \
# 0  Bloubergstrand is a lovely, cosy suburb near C...
# 1  Close to Eden on The Bay and lots of restauran...
# 2  It is probably the best hub in order to explor...
# 3                                                NaN
# 4  Durbanville is a really lovely village half an...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/3b654aa4-248e...    59072  ...
# 1  https://a0.muscache.com/pictures/a09b3f0d-d43b...    59318  ...
# 2  https://a0.muscache.com/pictures/4a8fceaa-655e...    59342  ...
# 3  https://a0.muscache.com/pictures/142776/5b6c9e...    59694  ...
# 4  https://a0.muscache.com/pictures/113126/f1bb90...    60196  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.94                   4.94                4.85
# 1                         NaN                    NaN                 NaN
# 2                        4.71                   4.86                5.00
# 3                        5.00                   5.00                4.00
# 4                         NaN                    NaN                 NaN
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                              5
# 2     NaN                f                              6
# 3     NaN                f                              1
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           5
# 2                                           1
# 3                                           1
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            5
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.33
# 1                                           0               NaN
# 2                                           0              0.05
# 3                                           0              0.01
# 4                                           0               NaN
#
# [5 rows x 79 columns]

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26877 entries, 0 to 26876
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            26877 non-null  int64
#  1   listing_url                                   26877 non-null  object
#  2   scrape_id                                     26877 non-null  int64
#  3   last_scraped                                  26877 non-null  object
#  4   source                                        26877 non-null  object
#  5   name                                          26876 non-null  object
#  6   description                                   26571 non-null  object
#  7   neighborhood_overview                         12832 non-null  object
#  8   picture_url                                   26877 non-null  object
#  9   host_id                                       26877 non-null  int64
#  10  host_url                                      26877 non-null  object
#  11  host_name                                     26871 non-null  object
#  12  host_since                                    26871 non-null  object
#  13  host_location                                 19807 non-null  object
#  14  host_about                                    13378 non-null  object
#  15  host_response_time                            20238 non-null  object
#  16  host_response_rate                            20238 non-null  object
#  17  host_acceptance_rate                          22947 non-null  object
#  18  host_is_superhost                             25778 non-null  object
#  19  host_thumbnail_url                            26871 non-null  object
#  20  host_picture_url                              26871 non-null  object
#  21  host_neighbourhood                            181 non-null    object
#  22  host_listings_count                           26871 non-null  float64
#  23  host_total_listings_count                     26871 non-null  float64
#  24  host_verifications                            26871 non-null  object
#  25  host_has_profile_pic                          26871 non-null  object
#  26  host_identity_verified                        26871 non-null  object
#  27  neighbourhood                                 12832 non-null  object
#  28  neighbourhood_cleansed                        26877 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      26877 non-null  float64
#  31  longitude                                     26877 non-null  float64
#  32  property_type                                 26877 non-null  object
#  33  room_type                                     26877 non-null  object
#  34  accommodates                                  26877 non-null  int64
#  35  bathrooms                                     22505 non-null  float64
#  36  bathrooms_text                                26641 non-null  object
#  37  bedrooms                                      26213 non-null  float64
#  38  beds                                          22649 non-null  float64
#  39  amenities                                     26877 non-null  object
#  40  price                                         22476 non-null  object
#  41  minimum_nights                                26877 non-null  int64
#  42  maximum_nights                                26877 non-null  int64
#  43  minimum_minimum_nights                        26875 non-null  float64
#  44  maximum_minimum_nights                        26875 non-null  float64
#  45  minimum_maximum_nights                        26875 non-null  float64
#  46  maximum_maximum_nights                        26875 non-null  float64
#  47  minimum_nights_avg_ntm                        26877 non-null  float64
#  48  maximum_nights_avg_ntm                        26877 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              25402 non-null  object
#  51  availability_30                               26877 non-null  int64
#  52  availability_60                               26877 non-null  int64
#  53  availability_90                               26877 non-null  int64
#  54  availability_365                              26877 non-null  int64
#  55  calendar_last_scraped                         26877 non-null  object
#  56  number_of_reviews                             26877 non-null  int64
#  57  number_of_reviews_ltm                         26877 non-null  int64
#  58  number_of_reviews_l30d                        26877 non-null  int64
#  59  availability_eoy                              26877 non-null  int64
#  60  number_of_reviews_ly                          26877 non-null  int64
#  61  estimated_occupancy_l365d                     26877 non-null  int64
#  62  estimated_revenue_l365d                       22476 non-null  float64
#  63  first_review                                  20753 non-null  object
#  64  last_review                                   20753 non-null  object
#  65  review_scores_rating                          20753 non-null  float64
#  66  review_scores_accuracy                        20752 non-null  float64
#  67  review_scores_cleanliness                     20752 non-null  float64
#  68  review_scores_checkin                         20749 non-null  float64
#  69  review_scores_communication                   20751 non-null  float64
#  70  review_scores_location                        20750 non-null  float64
#  71  review_scores_value                           20749 non-null  float64
#  72  license                                       129 non-null    object
#  73  instant_bookable                              26877 non-null  object
#  74  calculated_host_listings_count                26877 non-null  int64
#  75  calculated_host_listings_count_entire_homes   26877 non-null  int64
#  76  calculated_host_listings_count_private_rooms  26877 non-null  int64
#  77  calculated_host_listings_count_shared_rooms   26877 non-null  int64
#  78  reviews_per_month                             20753 non-null  float64
# dtypes: float64(24), int64(20), object(35)
# memory usage: 16.2+ MB

# %%
# Number of rows and columns
listing.shape
# Out:
# (26877, 79)

# %%
# Statistical summary
listing.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  2.687700e+04  2.687700e+04  2.687700e+04         26871.000000
# mean   7.010873e+17  2.025093e+13  2.253725e+08            15.203454
# std    5.826912e+17  1.078145e+01  2.190787e+08            38.959618
# min    1.500700e+04  2.025093e+13  2.528600e+04             0.000000
# 25%    3.809275e+07  2.025093e+13  3.865032e+07             1.000000
# 50%    8.500092e+17  2.025093e+13  1.314201e+08             3.000000
# 75%    1.262130e+18  2.025093e+13  4.152172e+08            10.000000
# max    1.519110e+18  2.025093e+13  7.209347e+08          1455.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed      latitude  \
# count               26871.000000                           0.0  26877.000000
# mean                   21.623795                           NaN    -33.954672
# std                    78.700961                           NaN      0.098098
# min                     0.000000                           NaN    -34.262840
# 25%                     1.000000                           NaN    -34.014110
# 50%                     3.000000                           NaN    -33.926913
# 75%                    12.000000                           NaN    -33.909730
# max                  8774.000000                           NaN    -33.485066
#
#           longitude  accommodates     bathrooms  ...  \
# count  26877.000000  26877.000000  22505.000000  ...
# mean      18.472992      3.756297      1.703377  ...
# std        0.124027      2.414683      1.204544  ...
# min       18.320200      1.000000      0.000000  ...
# 25%       18.401230      2.000000      1.000000  ...
# 50%       18.426327      3.000000      1.000000  ...
# 75%       18.483460      4.000000      2.000000  ...
# max       18.937458     16.000000     50.000000  ...
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               20752.000000           20749.000000
# mean                    4.767454               4.818619
# std                     0.426063               0.415889
# min                     1.000000               1.000000
# 25%                     4.720000               4.810000
# 50%                     4.890000               4.950000
# 75%                     5.000000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                 20751.000000            20750.000000
# mean                      4.825978                4.805823
# std                       0.414242                0.372897
# min                       1.000000                1.000000
# 25%                       4.830000                4.770000
# 50%                       4.960000                4.910000
# 75%                       5.000000                5.000000
# max                       5.000000                5.000000
#
#        review_scores_value  calculated_host_listings_count  \
# count         20749.000000                    26877.000000
# mean              4.712622                       12.691930
# std               0.456644                       28.609671
# min               1.000000                        1.000000
# 25%               4.670000                        1.000000
# 50%               4.830000                        2.000000
# 75%               5.000000                        8.000000
# max               5.000000                      175.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 26877.000000
# mean                                     10.778882
# std                                      26.174191
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       6.000000
# max                                     175.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  26877.000000
# mean                                       1.858876
# std                                       12.336569
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      156.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  26877.00000       20753.000000
# mean                                       0.02690           0.861893
# std                                        0.30691           1.034017
# min                                        0.00000           0.010000
# 25%                                        0.00000           0.170000
# 50%                                        0.00000           0.500000
# 75%                                        0.00000           1.150000
# max                                        9.00000          23.420000
#
# [8 rows x 44 columns]

# %%
# Check for missing values and shows all the columns
pd.set_option('display.max_rows', None)  
missing_values = listing.isna().sum()

print(missing_values)
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
# name                                                1
# description                                       306
# neighborhood_overview                           14045
# picture_url                                         0
# host_id                                             0
# host_url                                            0
# host_name                                           6
# host_since                                          6
# host_location                                    7070
# host_about                                      13499
# host_response_time                               6639
# host_response_rate                               6639
# host_acceptance_rate                             3930
# host_is_superhost                                1099
# host_thumbnail_url                                  6
# host_picture_url                                    6
# host_neighbourhood                              26696
# host_listings_count                                 6
# host_total_listings_count                           6
# host_verifications                                  6
# host_has_profile_pic                                6
# host_identity_verified                              6
# neighbourhood                                   14045
# neighbourhood_cleansed                              0
# neighbourhood_group_cleansed                    26877
# latitude                                            0
# longitude                                           0
# property_type                                       0
# room_type                                           0
# accommodates                                        0
# bathrooms                                        4372
# bathrooms_text                                    236
# bedrooms                                          664
# beds                                             4228
# amenities                                           0
# price                                            4401
# minimum_nights                                      0
# maximum_nights                                      0
# minimum_minimum_nights                              2
# maximum_minimum_nights                              2
# minimum_maximum_nights                              2
# maximum_maximum_nights                              2
# minimum_nights_avg_ntm                              0
# maximum_nights_avg_ntm                              0
# calendar_updated                                26877
# has_availability                                 1475
# availability_30                                     0
# availability_60                                     0
# availability_90                                     0
# availability_365                                    0
# calendar_last_scraped                               0
# number_of_reviews                                   0
# number_of_reviews_ltm                               0
# number_of_reviews_l30d                              0
# availability_eoy                                    0
# number_of_reviews_ly                                0
# estimated_occupancy_l365d                           0
# estimated_revenue_l365d                          4401
# first_review                                     6124
# last_review                                      6124
# review_scores_rating                             6124
# review_scores_accuracy                           6125
# review_scores_cleanliness                        6125
# review_scores_checkin                            6128
# review_scores_communication                      6126
# review_scores_location                           6127
# review_scores_value                              6128
# license                                         26748
# instant_bookable                                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                                6124
# dtype: int64

# %%
# Check for duplicates
listing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Observations**<br>
# - The data has 26877 rows and 79 columns
# - The dataset has numerous missing values
# - No duplicates in the data
# - The dataset is a mixture of numerous data types, integers, floats, objects/strings, among others.

# %% [markdown]
# ## 2.3 Exploratory Data Analysis

# %% [markdown]
# **What to Do:**
# ```python
# # Comprehensive statistical analysis
# # Distribution analysis for numerical features
# # Frequency analysis for categorical features
# # Correlation analysis between variables
# # Outlier detection using IQR, z-scores, or visualization
# ```
#
# **Key Tasks:**
# - Analyze target variable (price) distribution
# - Identify skewed distributions that need transformation
# - Find correlations between features and price
# - Detect outliers that could skew models
# - Understand feature variability and spread

# %% [markdown]
# ### Univariate Analysis

# %%
# Check for outliers using a box plot
plt.figure(figsize = (10, 8))
sns.boxplot(data = listing, orient = 'h')
plt.title('Box plot for detecting outliers')
# Out:
# Text(0.5, 1.0, 'Box plot for detecting outliers')

# %% [markdown]
# **Observation**<br>
# - No outliers shown in the box plot

# %%
# Remove the dollar signs in the target variable, ie. price
listing['price'] = listing['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
sns.histplot(listing['price'], bins=40)
plt.title('Distribution of price');
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Observation**<br>
# My histogram seems a bit wierd, but actually, the data is skewed to the left, meaning, most of the airbnb prices are actually cheap and not expensive.

# %%
figure, ax = plt.subplots()
sns.countplot(x='room_type', data=listing)
plt.title('Room type distribution')
ax.bar_label(ax.containers[0], label_type = 'edge');

# %% [markdown]
# **Observation**<br>
# The most common room type sought for by clients is an entire home or apartment by 22179 while the least sought for room is a shared room by 45.

# %%
# Distribution of property type
figure, ax = plt.subplots(figsize = (10, 10))
order = listing['property_type'].value_counts().head(15).index
sns.countplot(y='property_type', data=listing, order = order)
plt.title('Property type distribution (Top 15)')
ax.bar_label(ax.containers[0], label_type = 'edge');

# %% [markdown]
# **Observation**<br>
# From the above plot, entire rental unit is most sought for by clients with 11463 votes followed by entire home with 5497.

# %%
# Format the bathroom data. There doesn't exist a 1.5 bathroom 
# Only format the wrong values, leave the nan values as they are
listing['bathrooms'] = listing['bathrooms'].apply(
    lambda x: int(x) if pd.notnull(x) else np.nan
)

# %%
# Distribution of the bedrooms and beds
fig, axes = plt.subplots(1, 2, figsize=(19, 6))
sns.countplot(x='bedrooms', data=listing, ax=axes[0], palette='cool')
sns.countplot(x='bathrooms', data=listing, ax=axes[1], palette='mako')
axes[0].set_title('Bedrooms Distribution')
axes[1].set_title('Bathrooms Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**<br>
# Most Airbnbs have 1 to 5 bedrooms and 1 to 4 bathrooms.

# %%
# Distribution of superhosts
figure, ax = plt.subplots()
sns.countplot(x='host_is_superhost', data=listing, palette='pastel')
plt.title('Superhost Distribution')
ax.bar_label(ax.containers[0], label_type = 'edge')
plt.show();

# %% [markdown]
# **Observation**<br>
# There are few superhosts in Cape Town by 8454.

# %% [markdown]
# ### Bivariate Analysis

# %%
# Room type vs price
figure, ax = plt.subplots()
sns.barplot(x='room_type', y='price', data=listing, palette='Set2', errorbar = None)
plt.title('Price by Room Type')
plt.xticks(rotation=30)
ax.bar_label(ax.containers[0], label_type = 'edge')
plt.show();

# %% [markdown]
# **Observation**<br>
# The most expensive room is an entire home or apartment for `$3609.37`, while the cheapest room is a shared room for `$628.56`.

# %%
# Property type vs price, top 10
figure, ax = plt.subplots(figsize = (10, 8))
top_props = listing['property_type'].value_counts().head(10).index
sns.barplot(x='property_type', y='price', data=listing[listing['property_type'].isin(top_props)], errorbar = None)
plt.xticks(rotation=45)
plt.title('Price by Property Type (Top 10)')
ax.bar_label(ax.containers[0], label_type = 'edge')
plt.show();

# %% [markdown]
# **Observations**<br>
# An entire villa is the most expensive property for `$16576.70` followed by an entire home which goes for `$6198.10`.

# %%
# Neighbourhoods vs price
figure, ax = plt.subplots()
avg_price_neigh = listing.groupby('neighbourhood_cleansed')['price'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=avg_price_neigh.values, y=avg_price_neigh.index, palette = 'magma')
plt.title('Top 10 Expensive Neighborhoods')
plt.xlabel('Average Price')
plt.ylabel('Neighborhood')
ax.bar_label(ax.containers[0], label_type = 'edge')
plt.show();

# %% [markdown]
# **Observations**<br>
# The most expensive neighborhood to stay in is Ward 35, which goes for `$114408`, followed by Ward 116 for `$16272`. Among the top ten most expensive wards, ward 77 is the least costly neighbourhood, going for `$3284,40`.

# %%
# Prices vs Location
sns.scatterplot(x='longitude', y='latitude', hue='price', data=listing, palette='Spectral', alpha=0.6)
plt.title('Airbnb Prices by Location')
plt.show;

# %%
# Reviews vs ratings
fig, ax = plt.subplots(figsize=(6,5))
sns.scatterplot(x='number_of_reviews', y='review_scores_rating', data=listing, alpha=0.5)
plt.title('Reviews vs. Ratings', fontsize=14)
plt.xlabel('Number of Reviews')
plt.ylabel('Review Rating')
plt.show();

# %% [markdown]
# **Observation**<br>
# High reviews go hand in hand with high ratings.

# %% [markdown]
# ## 2.4 Data Quality Assessment

# %% [markdown]
# **What to Do:**
# - **Missing Value Analysis**: Percentage missing per column, patterns in missingness
# - **Data Consistency**: Check for logical inconsistencies (e.g., 0 bedrooms but accommodates 5)
# - **Duplicate Detection**: Identify and handle duplicate listings
# - **Value Validation**: Ensure values are within reasonable ranges
#
# **Quality Report Should Include:**
# - Missing value summary table
# - Data type consistency check
# - Logical validation results
# - Recommendations for handling each issue

# %% [markdown]
# ## 2.5 Visualization: Initial Insights

# %% [markdown]
# **What to Do:**
# ```python
# # Create key visualizations:
# # 1. Price distribution (histogram, boxplot)
# # 2. Geographic patterns (map of prices by neighborhood)
# # 3. Feature relationships (scatter plots, correlation heatmap)
# # 4. Categorical analysis (bar charts by property type, room type)
# ```
#
# **Key Visualizations:**
# - **Price Distribution**: Histogram + boxplot to understand spread and outliers
# - **Geographic Heatmap**: Map showing price concentrations across Cape Town
# - **Correlation Matrix**: Relationships between numerical features
# - **Feature vs Price**: Scatter plots for key numerical features
# - **Category Analysis**: Boxplots of price by neighborhood, property type

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# **Purpose:**
# Transform raw data into a clean, structured format suitable for machine learning models through cleaning, feature engineering, and preprocessing.

# %% [markdown]
# First, I'll choose the columns that I'll most probably use in achieving my objective, which makes it easier to work in data preparation instead of using the entire dataset.

# %%
relevant_columns = ['property_type', 'room_type', 'accommodates', 'amenities', 'bedrooms', 'beds', 'bathrooms', 'latitude', 'longitude', 'neighbourhood_cleansed', 
                   'host_is_superhost', 'host_listings_count', 'host_since', 'host_acceptance_rate', 'availability_365', 'number_of_reviews', 
                   'review_scores_rating', 'instant_bookable', 'review_scores_location', 'price']

# %%
df = listing[relevant_columns]
df.head()
# Out:
#                  property_type        room_type  accommodates  \
# 0                  Entire home  Entire home/apt             6
# 1           Entire rental unit  Entire home/apt             6
# 2  Private room in rental unit     Private room             2
# 3           Entire rental unit  Entire home/apt             2
# 4           Entire guest suite  Entire home/apt             3
#
#                                            amenities  bedrooms  beds  \
# 0  ["Bathtub", "Fire extinguisher", "Oven", "Port...       3.0   4.0
# 1  ["Hangers", "TV with standard cable", "Wifi", ...       3.0   5.0
# 2  ["Wifi", "Oven", "Beach essentials", "Body soa...       1.0   2.0
# 3  ["Wifi", "Free parking on premises", "TV", "Wa...       1.0   1.0
# 4  ["Fire extinguisher", "Hangers", "Wifi", "Free...       2.0   NaN
#
#    bathrooms   latitude  longitude neighbourhood_cleansed host_is_superhost  \
# 0        3.0 -33.800010  18.460630                Ward 23                 f
# 1        2.0 -33.788260  18.459400                Ward 23               NaN
# 2        1.0 -33.858356  18.490376                 Ward 4                 f
# 3        1.0 -33.911150  18.412350               Ward 115               NaN
# 4        NaN -33.830740  18.631420               Ward 112                 f
#
#    host_listings_count  host_since host_acceptance_rate  availability_365  \
# 0                  7.0  2009-12-01                  88%               230
# 1                  7.0  2009-12-02                  33%               264
# 2                  7.0  2009-12-02                  80%               314
# 3                  2.0  2009-12-03                  NaN               365
# 4                  1.0  2009-12-05                  NaN                 0
#
#    number_of_reviews  review_scores_rating instant_bookable  \
# 0                 47                  4.81                f
# 1                  0                   NaN                f
# 2                  7                  5.00                f
# 3                  2                  4.50                f
# 4                  0                   NaN                f
#
#    review_scores_location   price
# 0                    4.94  2315.0
# 1                     NaN  4785.0
# 2                    4.86  1118.0
# 3                    5.00  2250.0
# 4                     NaN     NaN

# %% [markdown]
# **What to Do:**
# ```python
# # Systematic cleaning operations:
# # Handle missing values (imputation, removal)
# # Remove or transform outliers
# # Fix data type inconsistencies
# # Standardize text formats
# # Handle duplicate entries
# ```
#
# **Specific Cleaning Tasks:**
# - **Price Cleaning**: Remove currency symbols, handle extreme values
# - **Missing Data**: Strategic imputation (mean, median, mode, or predictive)
# - **Text Cleaning**: Standardize amenities, descriptions, categories
# - **Geographic Data**: Validate coordinates, handle missing locations
# - **Temporal Data**: Convert date formats, extract useful components

# %% [markdown]
# #### 1. Handle missing values

# %%
# Check for missing values
df.isna().sum()
# Out:
# property_type                0
# room_type                    0
# accommodates                 0
# amenities                    0
# bedrooms                   664
# beds                      4228
# bathrooms                 4372
# latitude                     0
# longitude                    0
# neighbourhood_cleansed       0
# host_is_superhost         1099
# host_listings_count          6
# host_since                   6
# host_acceptance_rate      3930
# availability_365             0
# number_of_reviews            0
# review_scores_rating      6124
# instant_bookable             0
# review_scores_location    6127
# price                     4401
# dtype: int64

# %%
# Percentages of the missing values
df.isna().sum()*100/len(df)
# Out:
# property_type              0.000000
# room_type                  0.000000
# accommodates               0.000000
# amenities                  0.000000
# bedrooms                   2.470514
# beds                      15.730922
# bathrooms                 16.266696
# latitude                   0.000000
# longitude                  0.000000
# neighbourhood_cleansed     0.000000
# host_is_superhost          4.088998
# host_listings_count        0.022324
# host_since                 0.022324
# host_acceptance_rate      14.622168
# availability_365           0.000000
# number_of_reviews          0.000000
# review_scores_rating      22.785281
# instant_bookable           0.000000
# review_scores_location    22.796443
# price                     16.374595
# dtype: float64

# %%
df = df.dropna(subset = ['bedrooms', 'host_is_superhost'])
df = df.reset_index(drop = True)
df.isna().sum()*100/len(df)
# Out:
# property_type              0.000000
# room_type                  0.000000
# accommodates               0.000000
# amenities                  0.000000
# bedrooms                   0.000000
# beds                      13.749602
# bathrooms                 14.322668
# latitude                   0.000000
# longitude                  0.000000
# neighbourhood_cleansed     0.000000
# host_is_superhost          0.000000
# host_listings_count        0.023878
# host_since                 0.023878
# host_acceptance_rate      13.658071
# availability_365           0.000000
# number_of_reviews          0.000000
# review_scores_rating      22.437122
# instant_bookable           0.000000
# review_scores_location    22.449061
# price                     14.334607
# dtype: float64

# %%
# Handle the missing in host_acceptance_rate
# It's categorical data, so I'll fill the missing values with the mode
df['host_acceptance_rate'].fillna(df['host_acceptance_rate'].mode()[0], inplace = True)

# %%
df.isna().sum()*100/len(df)
# Out:
# property_type              0.000000
# room_type                  0.000000
# accommodates               0.000000
# amenities                  0.000000
# bedrooms                   0.000000
# beds                      13.749602
# bathrooms                 14.322668
# latitude                   0.000000
# longitude                  0.000000
# neighbourhood_cleansed     0.000000
# host_is_superhost          0.000000
# host_listings_count        0.023878
# host_since                 0.023878
# host_acceptance_rate       0.000000
# availability_365           0.000000
# number_of_reviews          0.000000
# review_scores_rating      22.437122
# instant_bookable           0.000000
# review_scores_location    22.449061
# price                     14.334607
# dtype: float64

# %% [markdown]
# The remaining missing values are floats. I have to determine if the data in those columns are skewed so that I'll known which method to use in order to fill their missing values.

# %%
# Checking how the dta is distributed
fig, axes = plt.subplots(3, 1, figsize=(25, 15))
sns.countplot(x='review_scores_rating', data=listing, ax=axes[0], palette='mako')
sns.countplot(x='review_scores_location', data=listing, ax=axes[1], palette='pastel')
sns.countplot(x='beds', data=listing, ax=axes[2], palette='cool')
axes[0].set_title('Ratings Distribution')
axes[1].set_title('Location Reviews Distribution')
axes[2].set_title('Beds Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**<br>
# The graphs may not be fully clear due to their large amount, but from what is visible, one can see that rating and location reviews are skewed to the right, while beds is skewed to the left, which means that I'll use the median to fill the missing values. Bathrooms underwent some analysis in the data understanding, but it's also skewed to the left.

# %%
cols = ['beds', 'review_scores_rating', 'bathrooms', 'review_scores_location'] 

# Fill the each column with its median
for col in cols:
    df[col].fillna(df[col].median(), inplace=True)

# %%
df.isna().sum()*100/len(df)
# Out:
# property_type              0.000000
# room_type                  0.000000
# accommodates               0.000000
# amenities                  0.000000
# bedrooms                   0.000000
# beds                       0.000000
# bathrooms                  0.000000
# latitude                   0.000000
# longitude                  0.000000
# neighbourhood_cleansed     0.000000
# host_is_superhost          0.000000
# host_listings_count        0.023878
# host_since                 0.023878
# host_acceptance_rate       0.000000
# availability_365           0.000000
# number_of_reviews          0.000000
# review_scores_rating       0.000000
# instant_bookable           0.000000
# review_scores_location     0.000000
# price                     14.334607
# dtype: float64

# %%
df.dtypes
# Out:
# property_type              object
# room_type                  object
# accommodates                int64
# amenities                  object
# bedrooms                  float64
# beds                      float64
# bathrooms                 float64
# latitude                  float64
# longitude                 float64
# neighbourhood_cleansed     object
# host_is_superhost          object
# host_listings_count       float64
# host_since                 object
# host_acceptance_rate       object
# availability_365            int64
# number_of_reviews           int64
# review_scores_rating      float64
# instant_bookable           object
# review_scores_location    float64
# price                     float64
# dtype: object

# %% [markdown]
# #### 2. Standardizing formats.
# Some features such as bedrooms need to be well formatted. For this example, bedrooms are not calculated by floats, is, half a bedroom (2.5), so I need to change it to an integer.

# %%
# Change the below columns from floats to integers
format_cols = ['bedrooms', 'beds', 'bathrooms']

df[format_cols] = df[format_cols].astype('int64')

# %%
df.dtypes
# Out:
# property_type              object
# room_type                  object
# accommodates                int64
# amenities                  object
# bedrooms                    int64
# beds                        int64
# bathrooms                   int64
# latitude                  float64
# longitude                 float64
# neighbourhood_cleansed     object
# host_is_superhost          object
# host_listings_count       float64
# host_since                 object
# host_acceptance_rate       object
# availability_365            int64
# number_of_reviews           int64
# review_scores_rating      float64
# instant_bookable           object
# review_scores_location    float64
# price                     float64
# dtype: object

# %%
plt.figure(figsize = (10, 8))
sns.boxplot(data = df, orient = 'h')
plt.title('Box plot for detecting outliers')
# Out:
# Text(0.5, 1.0, 'Box plot for detecting outliers')

# %% [markdown]
# **Observation**<br>
# From the above box plot, there are some outliers especially in the price column. I will not be removing them as I will be using them as I achieve the objective.

# %%
df.shape
# Out:
# (25128, 20)

# %% [markdown]
# ## 3.2 Advanced Feature Engineering

# %% [markdown]
# **What to Do:**
# ```python
# # Create new features that capture domain knowledge:
# # Geospatial features (distance to landmarks, neighborhood clusters)
# # Temporal features (seasonality, time-based patterns)
# # Amenity analysis (counts, premium amenities, unique combinations)
# # Host experience metrics (days hosting, response efficiency)
# # Text-based features (description length, sentiment, keywords)
# ```
#
# **Feature Engineering Categories:**
# - **Geospatial**: Distance to V&A Waterfront, Table Mountain, beaches
# - **Temporal**: High/low season indicators, month, day of week
# - **Amenity-Based**: Luxury score, family-friendly score, business amenities
# - **Host-Based**: Experience level, responsiveness metrics, superhost status
# - **Property-Based**: Size metrics, quality indicators, unique selling points

# %% [markdown]
# ## 3.3 Feature Selection

# %% [markdown]
# **What to Do:**
# ```python
# # Systematic feature evaluation:
# # Correlation analysis with target variable
# # Multicollinearity check between features
# # Domain knowledge-based selection
# # Statistical tests for feature importance
# # Model-based feature importance (using initial models)
# ```
#
# **Selection Methods:**
# - **Statistical**: Correlation coefficients, mutual information
# - **Model-Based**: Feature importance from tree-based models
# - **Domain-Driven**: Business relevance and interpretability
# - **Practical**: Computational efficiency and data availability

# %% [markdown]
# ## 3.4 Data Transformation

# %% [markdown]
# **What to Do:**
# ```python
# # Prepare data for modeling:
# # Scaling numerical features (StandardScaler, MinMaxScaler)
# # Encoding categorical variables (One-Hot, Label, Target Encoding)
# # Transforming skewed variables (log, sqrt, Box-Cox)
# # Creating interaction terms
# # Handling class imbalance if applicable
# ```
#
# **Transformation Tasks:**
# - **Numerical**: Scale features to similar ranges
# - **Categorical**: Convert to numerical representations
# - **Target Variable**: Log-transform price to handle skewness
# - **Text Data**: Vectorize descriptions or extract features
# - **High Cardinality**: Use techniques like target encoding or embedding

# %% [markdown]
# ## 3.5 Train-Test Split & Validation Strategy

# %% [markdown]
# **What to Do:**
# ```python
# # Data partitioning for robust evaluation:
# # Time-based split (if temporal component exists)
# # Stratified sampling (if important categorical distributions)
# # Cross-validation setup (k-fold, stratified k-fold)
# # Holdout validation set creation
# ```
#
# **Validation Strategy:**
# - **Split Ratio**: Typically 70-80% training, 20-30% testing
# - **Temporal Consideration**: Ensure no data leakage from future to past
# - **Stratification**: Maintain similar distributions in splits
# - **Cross-Validation**: Use k-fold for hyperparameter tuning
# - **Final Evaluation**: Holdout test set for unbiased performance estimate

# %% [markdown]
# ## **Key Deliverables from These Stages:**
#
# ### **Data Understanding Deliverables:**
# 1. Data quality report with issue documentation
# 2. EDA summary with key insights and visualizations
# 3. Feature documentation with descriptions and types
# 4. Initial hypothesis about important pricing factors
#
# ### **Data Preparation Deliverables:**
# 1. Cleaned dataset ready for modeling
# 2. Feature engineering documentation
# 3. Preprocessing pipeline code
# 4. Train/validation/test splits
# 5. Feature selection rationale
#
# ### **Success Criteria for These Stages:**
# - ✅ All data quality issues identified and addressed
# - ✅ Comprehensive feature set created and documented
# - ✅ Data properly formatted for machine learning algorithms
# - ✅ No data leakage between training and testing sets
# - ✅ Clear rationale for all preprocessing decisions
#
# These stages are critical for building reliable models - the quality of your data preparation directly impacts your model's performance and the credibility of your results.

# %% [markdown]
# ## 4. Modeling

# %% [markdown]
# ### 4.1 Baseline Model

# %%
# Code Cell 9: Simple regression baseline
# Linear regression or decision tree as reference

# %% [markdown]
# ### 4.2 Traditional Machine Learning Models

# %%
# Code Cell 10: Multiple traditional models
# Random Forest, XGBoost, Gradient Boosting

# %% [markdown]
# ### 4.3 Hyperparameter Tuning

# %%
# Code Cell 11: Model optimization
# Grid search, random search, Bayesian optimization

# %% [markdown]
# ### 4.4 Deep Learning Approach

# %%
# Code Cell 12: Neural network implementation
# Feedforward networks, embedding layers

# %% [markdown]
# ### 4.5 Model Training Pipeline

# %%
# Code Cell 13: Training workflow
# Cross-validation, early stopping, checkpointing

# %% [markdown]
# # 5. Evaluation

# %% [markdown]
# ## 5.1 Model Performance Comparison

# %%
# Code Cell 14: Comprehensive metrics
# RMSE, MAE, R², business metrics

# %% [markdown]
# ## 5.2 Advanced Model Interpretation

# %%
# Code Cell 15: Explainability tools
# SHAP analysis, feature importance, partial dependence plots

# %% [markdown]
# ## 5.3 Error Analysis

# %%
# Code Cell 16: Residual analysis
# Error patterns, worst-case predictions, bias detection

# %% [markdown]
# ## 5.4 Business Impact Assessment

# %% [markdown]
# *Translation of model performance to business value*

# %% [markdown]
# ## 5.5 Model Selection Justification
# *Final model choice with rationale*

# %% [markdown]
# # 6. Advanced Topics

# %% [markdown]
# ## 6.1 Deep Learning vs Traditional ML Comparison

# %%
# Code Cell 17: Performance comparison
# Strengths/weaknesses of each approach

# %% [markdown]
# ## 6.2 Feature Engineering Impact

# %%
# Code Cell 18: Ablation studies
# Impact of different feature groups on performance

# %% [markdown]
# ## 6.3 Geographic Analysis

# %%
# Code Cell 19: Spatial patterns
# Neighborhood effects, location-based insights

# %% [markdown]
# ## 6.4 Seasonality and Temporal Patterns

# %%
# Code Cell 20: Time-based analysis
# Price fluctuations, booking patterns

# %% [markdown]
# # 7. Deployment

# %% [markdown]
# ## 7.1 Production Pipeline

# %%
# Code Cell 21: Deployment-ready code
# Model serialization, preprocessing pipeline

# %% [markdown]
# ## 7.2 Streamlit Application

# %%
# Code Cell 22: Web app implementation
# User interface for price predictions

# %% [markdown]
# ## 7.3 API Design (Optional)

# %%
# Code Cell 23: REST API skeleton
# For potential integration with other systems

# %% [markdown]
# # 8. Business Recommendations

# %% [markdown]
# ## 8.1 Key Pricing Drivers
# *Top features influencing Airbnb prices in Cape Town*

# %% [markdown]
# ## 8.2 Host Recommendations
# - Optimal pricing strategies
# - Feature prioritization for maximum ROI
# - Seasonal adjustment guidance

# %% [markdown]
# ## 8.3 Platform Suggestions
# *Recommendations for Airbnb and similar platforms*

# %% [markdown]
# # 9. Conclusion

# %% [markdown]
# ## 9.1 Project Summary
# *Key achievements and model performance*

# %% [markdown]
# ## 9.2 Limitations
# *Data constraints, model limitations, assumptions*

# %% [markdown]
# ## 9.3 Future Work
# - Expansion to other African cities
# - Real-time pricing adjustments
# - Advanced deep learning architectures

# %% [markdown]
# ## **Implementation Notes for Each Section:**
#
# ### **Code Cell Structure:**
# ```python
# # Each major code cell should include:
# """
# Purpose: Clear objective of the cell
# Input: What data/objects it uses
# Output: What it produces
# Dependencies: What needs to run before this
# """
# ```
#
# ### **Advanced ML Communication Elements:**
# - **Narrative**: Each section has clear business context
# - **Technical Depth**: Advanced concepts explained accessibly
# - **Visual Storytelling**: Charts with clear interpretations
# - **Business Translation**: Technical results connected to business impact
#
# ### **Exceeding Objectives Checklist:**
# - [ ] Multiple Python packages beyond scikit-learn
# - [ ] Advanced feature engineering demonstrated
# - [ ] Model explainability tools implemented
# - [ ] Cross-package model comparison
# - [ ] Comprehensive evaluation metrics
# - [ ] Professional documentation standards
# - [ ] Clear business narrative throughout
